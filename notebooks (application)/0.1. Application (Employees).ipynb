# %% [markdown]
# ## --- 0. Libraries Importing ---

# %%
# ignore warnings
import warnings
warnings.filterwarnings("ignore")

# dataframe manipulation
import numpy as np
import pandas as pd
pd.set_option('display.max_rows', None)

# datetime
from datetime import datetime

# set notebook width to 100%
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))

# Path
import os
from matplotlib import Path
os.chdir(Path(os.getcwd()).parent)

# libraries
from libraries.Visualization import (plot_distribution,
                                     plot_performances,
                                     plot_classes_performances)

from libraries.Algorithms import (DecisionTree,
                                  RandomForest)

# text coloring
from termcolor import colored

# evaluation
from sklearn.metrics import (recall_score)
# Out:
# <style>.container { width:100% !important; }</style>
# <style>.container { width:100% !important; }</style>
# <style>.container { width:100% !important; }</style>

# %% [markdown]
# ## --- 0.1. Parameters ---

# %%
uc_name = 'employees'
target_column = 'LeaveOrNot'

num_runs = 5
number_of_trees_values = [6, 7, 8, 9, 10]
alpha_values = [0.01, 0.05, 0.1, 1]

# %% [markdown]
# # 1. Data Loading

# %%
(X_train, X_test, y_train, y_test) = (
                                        (
                                            pd
                                            .read_csv(f'data/prepared_data/{uc_name}/X_train.csv',
                                                      low_memory=False)
                                        ),
                                        
                                        (
                                            pd
                                            .read_csv(f'data/prepared_data/{uc_name}/X_test.csv',
                                                      low_memory=False)
                                        ),
    
                                        (
                                            pd
                                            .read_csv(f'data/prepared_data/{uc_name}/y_train.csv',
                                                      low_memory=False)
                                            .loc[:, target_column]
                                        ),
                                        
                                        (
                                            pd
                                            .read_csv(f'data/prepared_data/{uc_name}/y_test.csv',
                                                      low_memory=False)
                                            .loc[:, target_column]
                                        )
                                     )

plot_distribution(df=pd.DataFrame(y_train),
                  column=target_column)
print(f"Shape -> X_train: {X_train.shape}, y_train: {y_train.shape}.")

plot_distribution(df=pd.DataFrame(y_test),
                  column=target_column)
print(f"Shape -> X_test: {X_test.shape}, y_test: {y_test.shape}.")
# Out:
# Shape -> X_train: (2240, 9), y_train: (2240,).
# Shape -> X_test: (960, 9), y_test: (960,).

# %% [markdown]
# # 2. Model building

# %% [markdown]
# ## --- 2.1. RAFO ---

# %%
time_measurements = {}

evaluations_train_class_1 = {}
evaluations_test_class_1 = {}

evaluations_train_class_0 = {}
evaluations_test_class_0 = {}

for i in range(num_runs):
    print(f'''\t\t\t\t\t\t\t\t{colored(f'<<<<<<<< RUN {i} >>>>>>>>', 'blue', attrs=['bold'])}''')
    ########################## 0. TIME ##########################
    df_time = (pd
               .DataFrame(index=number_of_trees_values,
                          columns=alpha_values)
              )
    
    df_time.index.name = 'Number Of Trees'
    df_time.columns.name = 'Alpha Value'
    
    ########################## 1. CLASS 1 ##########################
    df_evaluation_train_class_1 = (pd
                                   .DataFrame(index=number_of_trees_values,
                                              columns=alpha_values)                           
                                  )
    
    df_evaluation_train_class_1.index.name = 'Number Of Trees'
    df_evaluation_train_class_1.columns.name = 'Alpha Value'
    
    df_evaluation_test_class_1 = (pd
                                  .DataFrame(index=number_of_trees_values,
                                             columns=alpha_values)
                                 )
    
    df_evaluation_test_class_1.index.name = 'Number Of Trees'
    df_evaluation_test_class_1.columns.name = 'Alpha Value'
    
    ########################## 2. CLASS 0 ##########################
    df_evaluation_train_class_0 = (pd
                                   .DataFrame(index=number_of_trees_values,
                                              columns=alpha_values)                           
                                  )
    
    df_evaluation_train_class_0.index.name = 'Number Of Trees'
    df_evaluation_train_class_0.columns.name = 'Alpha Value'
    
    df_evaluation_test_class_0 = (pd
                                  .DataFrame(index=number_of_trees_values,
                                             columns=alpha_values)
                                 )
    
    df_evaluation_test_class_0.index.name = 'Number Of Trees'
    df_evaluation_test_class_0.columns.name = 'Alpha Value'

    for number_of_trees in number_of_trees_values:
        for alpha in alpha_values:
            time_started = datetime.now()
            
            rafo = RandomForest(number_of_trees=number_of_trees,
                                max_depth=5,
                                mtry=6,
                                alpha=alpha)
            print(rafo)
        
            rafo.fit(X_train, y_train)
        
            train_predictions = rafo.predict(X_train)
            test_predictions = rafo.predict(X_test)
            
            time_finished = datetime.now()
        
            df_evaluation_train_class_1.loc[number_of_trees, alpha] = recall_score(y_true=y_train.values,
                                                                                   y_pred=train_predictions,
                                                                                   pos_label=1)
            
            df_evaluation_train_class_0.loc[number_of_trees, alpha] = recall_score(y_true=y_train.values,
                                                                                   y_pred=train_predictions,
                                                                                   pos_label=0)
            
            df_evaluation_test_class_1.loc[number_of_trees, alpha] = recall_score(y_true=y_test.values,
                                                                                  y_pred=test_predictions,
                                                                                  pos_label=1)
            
            df_evaluation_test_class_0.loc[number_of_trees, alpha] = recall_score(y_true=y_test.values,
                                                                                  y_pred=test_predictions,
                                                                                  pos_label=0)
            
            df_time.loc[number_of_trees, alpha] = ((time_finished - time_started).seconds / 60)
        
    print(f'''\t\t\t\t\t\t\t\t{colored(f'*** RECALL -> TRAIN SET ***', 'blue', attrs=['bold'])}''')
    plot_classes_performances(df_c0=df_evaluation_train_class_0,
                              df_c1=df_evaluation_train_class_1,
                              df_t=df_time,
                              x_label='Alpha Values',
                              y_label='Number Of Trees',
                              title_0='Class 0',
                              title_1='Class 1',
                              title_t='Time Measurements (In Minutes)')
    
    print(f'''\t\t\t\t\t\t\t\t{colored(f'*** RECALL -> TEST SET ***', 'blue', attrs=['bold'])}''')
    plot_classes_performances(df_c0=df_evaluation_test_class_0,
                              df_c1=df_evaluation_test_class_1,
                              df_t=df_time,
                              x_label='Alpha Values',
                              y_label='Number Of Trees',
                              title_0='Class 0',
                              title_1='Class 1',
                              title_t='Time Measurements (In Minutes)')
    
    evaluations_train_class_1[f'num_run: {i}'] = df_evaluation_train_class_1
    evaluations_test_class_1[f'num_run: {i}'] = df_evaluation_test_class_1
    
    evaluations_train_class_0[f'num_run: {i}'] = df_evaluation_train_class_0
    evaluations_test_class_0[f'num_run: {i}'] = df_evaluation_test_class_0
    
    time_measurements[f'num_run: {i}'] = df_time
    
evaluations_train_class_1_avg = (pd
                                 .DataFrame(index=number_of_trees_values,
                                            columns=alpha_values,
                                            data=0)
                                )

evaluations_test_class_1_avg = (pd
                                .DataFrame(index=number_of_trees_values,
                                           columns=alpha_values,
                                           data=0)
                               )

evaluations_train_class_0_avg = (pd
                                 .DataFrame(index=number_of_trees_values,
                                            columns=alpha_values,
                                            data=0)
                                )

evaluations_test_class_0_avg = (pd
                                .DataFrame(index=number_of_trees_values,
                                           columns=alpha_values,
                                           data=0)
                               )

time_measurements_avg = (pd
                         .DataFrame(index=number_of_trees_values,
                                    columns=alpha_values,
                                    data=0)
                        )

for i in range(num_runs):
    evaluations_train_class_1_avg = (evaluations_train_class_1_avg + evaluations_train_class_1[f'num_run: {i}'])
    evaluations_test_class_1_avg = (evaluations_test_class_1_avg + evaluations_test_class_1[f'num_run: {i}'])
    evaluations_train_class_0_avg = (evaluations_train_class_0_avg + evaluations_train_class_0[f'num_run: {i}'])
    evaluations_test_class_0_avg = (evaluations_test_class_0_avg + evaluations_test_class_0[f'num_run: {i}'])
    time_measurements_avg = (time_measurements_avg + time_measurements[f'num_run: {i}'])
        
evaluations_train_class_1_avg = (evaluations_train_class_1_avg / num_runs)
evaluations_test_class_1_avg = (evaluations_test_class_1_avg / num_runs)
evaluations_train_class_0_avg = (evaluations_train_class_0_avg / num_runs)
evaluations_test_class_0_avg = (evaluations_test_class_0_avg / num_runs)
time_measurements_avg = (time_measurements_avg / num_runs)

print(f'''\t\t\t\t\t\t\t\t{colored(f'*** AVERAGE TRAIN RECALL THROUGH {num_runs} RUNS ***', 'blue', attrs=['bold'])}''')
plot_classes_performances(df_c0=evaluations_train_class_0_avg,
                          df_c1=evaluations_train_class_1_avg,
                          df_t=time_measurements_avg,
                          x_label='Alpha Values',
                          y_label='Number Of Trees',
                          title_0='Class 0',
                          title_1='Class 1',
                          title_t='Time Measurements (In Minutes)')

print(f'''\t\t\t\t\t\t\t\t{colored(f'*** AVERAGE TEST RECALL THROUGH {num_runs} RUNS ***', 'blue', attrs=['bold'])}''')
plot_classes_performances(df_c0=evaluations_test_class_0_avg,
                          df_c1=evaluations_test_class_1_avg,
                          df_t=time_measurements_avg,
                          x_label='Alpha Values',
                          y_label='Number Of Trees',
                          title_0='Class 0',
                          title_1='Class 1',
                          title_t='Time Measurements (In Minutes)')
# Out:
# 								<<<<<<<< RUN 0 >>>>>>>>
#
#     **********************************************************
#                        RANDOM FOREST MODEL
#
#       ------------------ Hyperparameters -------------------
#         num_trees -> 6
#         sample_size -> 1
#         replace -> False
#         splitting_rule -> gini
#         max_depth -> 5
#         min_bucket -> 1
#         mtry -> 6
#         alpha -> 0.01
#         handle_outliers -> False
#         weight_classes -> False
#         uniform_strength -> 0
#       ------------------------------------------------------
#
#     **********************************************************
#
# **********************************************************
# TRAINING STARTED...
#
# TREE (0) (took: 0.02 mins).
# TREE (1) (took: 0.02 mins).
# TREE (2) (took: 0.02 mins).
# TREE (3) (took: 0.02 mins).
# TREE (4) (took: 0.02 mins).
# TREE (5) (took: 0.02 mins).
#
# TRAINING FINISHED!
#
# TRAINING TOOK: 0.1 mins.
# **********************************************************
#
#
#     **********************************************************
#                        RANDOM FOREST MODEL
#
#       ------------------ Hyperparameters -------------------
#         num_trees -> 6
#         sample_size -> 1
#         replace -> False
#         splitting_rule -> gini
#         max_depth -> 5
#         min_bucket -> 1
#         mtry -> 6
#         alpha -> 0.05
#         handle_outliers -> False
#         weight_classes -> False
#         uniform_strength -> 0
#       ------------------------------------------------------
#
#     **********************************************************
#
# **********************************************************
# TRAINING STARTED...
#
# TREE (0) (took: 0.0 mins).
# TREE (1) (took: 0.03 mins).
# TREE (2) (took: 0.02 mins).
# TREE (3) (took: 0.03 mins).
# TREE (4) (took: 0.03 mins).
# TREE (5) (took: 0.02 mins).
#
# TRAINING FINISHED!
#
# TRAINING TOOK: 0.13 mins.
# **********************************************************
#
#
#     **********************************************************
#                        RANDOM FOREST MODEL
#
#       ------------------ Hyperparameters -------------------
#         num_trees -> 6
#         sample_size -> 1
#         replace -> False
#         splitting_rule -> gini
#         max_depth -> 5
#         min_bucket -> 1
#         mtry -> 6
#         alpha -> 0.1
#         handle_outliers -> False
#         weight_classes -> False
#         uniform_strength -> 0
#       ------------------------------------------------------
#
#     **********************************************************
#
# **********************************************************
# TRAINING STARTED...
#
# TREE (0) (took: 0.02 mins).
# TREE (1) (took: 0.13 mins).
# TREE (2) (took: 0.02 mins).
# TREE (3) (took: 0.02 mins).
# TREE (4) (took: 0.02 mins).
# TREE (5) (took: 0.02 mins).
#
# TRAINING FINISHED!
#
# TRAINING TOOK: 0.22 mins.
# **********************************************************
#
#
#     **********************************************************
#                        RANDOM FOREST MODEL
#
#       ------------------ Hyperparameters -------------------
#         num_trees -> 6
#         sample_size -> 1
#         replace -> False
#         splitting_rule -> gini
#         max_depth -> 5
#         min_bucket -> 1
#         mtry -> 6
#         alpha -> 1
#         handle_outliers -> False
#         weight_classes -> False
#         uniform_strength -> 0
#       ------------------------------------------------------
#
#     **********************************************************
#
# **********************************************************
# TRAINING STARTED...
#
# TREE (0) (took: 1.2 mins).
# TREE (1) (took: 1.3 mins).
# TREE (2) (took: 1.42 mins).
# TREE (3) (took: 0.78 mins).
# TREE (4) (took: 1.37 mins).
# TREE (5) (took: 1.52 mins).
#
# TRAINING FINISHED!
#
# TRAINING TOOK: 7.58 mins.
# **********************************************************
#
#
#     **********************************************************
#                        RANDOM FOREST MODEL
#
#       ------------------ Hyperparameters -------------------
#         num_trees -> 7
#         sample_size -> 1
#         replace -> False
#         splitting_rule -> gini
#         max_depth -> 5
#         min_bucket -> 1
#         mtry -> 6
#         alpha -> 0.01
#         handle_outliers -> False
#         weight_classes -> False
#         uniform_strength -> 0
#       ------------------------------------------------------
#
#     **********************************************************
#
# **********************************************************
# TRAINING STARTED...
#
# TREE (0) (took: 0.0 mins).
# TREE (1) (took: 0.0 mins).
# TREE (2) (took: 0.02 mins).
# TREE (3) (took: 0.02 mins).
# TREE (4) (took: 0.02 mins).
# TREE (5) (took: 0.0 mins).
# TREE (6) (took: 0.02 mins).
#
# TRAINING FINISHED!
#
# TRAINING TOOK: 0.07 mins.
# **********************************************************
#
#
#     **********************************************************
#                        RANDOM FOREST MODEL
#
#       ------------------ Hyperparameters -------------------
#         num_trees -> 7
#         sample_size -> 1
#         replace -> False
#         splitting_rule -> gini
#         max_depth -> 5
#         min_bucket -> 1
#         mtry -> 6
#         alpha -> 0.05
#         handle_outliers -> False
#         weight_classes -> False
#         uniform_strength -> 0
#       ------------------------------------------------------
#
#     **********************************************************
#
# **********************************************************
# TRAINING STARTED...
#
# TREE (0) (took: 0.02 mins).
# TREE (1) (took: 0.02 mins).
# TREE (2) (took: 0.02 mins).
# TREE (3) (took: 0.08 mins).
# TREE (4) (took: 0.08 mins).
# TREE (5) (took: 0.02 mins).
# TREE (6) (took: 0.02 mins).
#
# TRAINING FINISHED!
#
# TRAINING TOOK: 0.25 mins.
# **********************************************************
#
#
#     **********************************************************
#                        RANDOM FOREST MODEL
#
#       ------------------ Hyperparameters -------------------
#         num_trees -> 7
#         sample_size -> 1
#         replace -> False
#         splitting_rule -> gini
#         max_depth -> 5
#         min_bucket -> 1
#         mtry -> 6
#         alpha -> 0.1
#         handle_outliers -> False
#         weight_classes -> False
#         uniform_strength -> 0
#       ------------------------------------------------------
#
#     **********************************************************
#
# **********************************************************
# TRAINING STARTED...
# TREE (0) (took: 0.03 mins).
# TREE (1) (took: 0.03 mins).
# TREE (2) (took: 0.02 mins).
# TREE (3) (took: 0.02 mins).
# TREE (4) (took: 0.02 mins).
# TREE (5) (took: 0.02 mins).
# TREE (6) (took: 0.1 mins).
#
# TRAINING FINISHED!
#
# TRAINING TOOK: 0.23 mins.
# **********************************************************
#
#
#     **********************************************************
#                        RANDOM FOREST MODEL
#
#       ------------------ Hyperparameters -------------------
#         num_trees -> 7
#         sample_size -> 1
#         replace -> False
#         splitting_rule -> gini
#         max_depth -> 5
#         min_bucket -> 1
#         mtry -> 6
#         alpha -> 1
#         handle_outliers -> False
#         weight_classes -> False
#         uniform_strength -> 0
#       ------------------------------------------------------
#
#     **********************************************************
#
# **********************************************************
# TRAINING STARTED...
#
# TREE (0) (took: 1.35 mins).
# TREE (1) (took: 1.45 mins).
# TREE (2) (took: 1.5 mins).
# TREE (3) (took: 1.37 mins).
# TREE (4) (took: 1.3 mins).
# TREE (5) (took: 1.37 mins).
# TREE (6) (took: 1.02 mins).
#
# TRAINING FINISHED!
#
# TRAINING TOOK: 9.35 mins.
# **********************************************************
#
#
#     **********************************************************
#                        RANDOM FOREST MODEL
#
#       ------------------ Hyperparameters -------------------
#         num_trees -> 8
#         sample_size -> 1
#         replace -> False
#         splitting_rule -> gini
#         max_depth -> 5
#         min_bucket -> 1
#         mtry -> 6
#         alpha -> 0.01
#         handle_outliers -> False
#         weight_classes -> False
#         uniform_strength -> 0
#       ------------------------------------------------------
#
#     **********************************************************
#
# **********************************************************
# TRAINING STARTED...
#
# TREE (0) (took: 0.02 mins).
# TREE (1) (took: 0.02 mins).
# TREE (2) (took: 0.0 mins).
# TREE (3) (took: 0.02 mins).
# TREE (4) (took: 0.02 mins).
# TREE (5) (took: 0.03 mins).
# TREE (6) (took: 0.02 mins).
# TREE (7) (took: 0.02 mins).
#
# TRAINING FINISHED!
#
# TRAINING TOOK: 0.13 mins.
# **********************************************************
#
#
#     **********************************************************
#                        RANDOM FOREST MODEL
#
#       ------------------ Hyperparameters -------------------
#         num_trees -> 8
#         sample_size -> 1
#         replace -> False
#         splitting_rule -> gini
#         max_depth -> 5
#         min_bucket -> 1
#         mtry -> 6
#         alpha -> 0.05
#         handle_outliers -> False
#         weight_classes -> False
#         uniform_strength -> 0
#       ------------------------------------------------------
#
#     **********************************************************
#
# **********************************************************
# TRAINING STARTED...
#
# TREE (0) (took: 0.02 mins).
# TREE (1) (took: 0.02 mins).
# TREE (2) (took: 0.02 mins).
# TREE (3) (took: 0.0 mins).
# TREE (4) (took: 0.02 mins).
# TREE (5) (took: 0.02 mins).
# TREE (6) (took: 0.02 mins).
# TREE (7) (took: 0.02 mins).
#
# TRAINING FINISHED!
#
# TRAINING TOOK: 0.12 mins.
# **********************************************************
#
#
#     **********************************************************
#                        RANDOM FOREST MODEL
#
#       ------------------ Hyperparameters -------------------
#         num_trees -> 8
#         sample_size -> 1
#         replace -> False
#         splitting_rule -> gini
#         max_depth -> 5
#         min_bucket -> 1
#         mtry -> 6
#         alpha -> 0.1
#         handle_outliers -> False
#         weight_classes -> False
#         uniform_strength -> 0
#       ------------------------------------------------------
#
#     **********************************************************
#
# **********************************************************
# TRAINING STARTED...
#
# TREE (0) (took: 0.08 mins).
# TREE (1) (took: 0.03 mins).
# TREE (2) (took: 0.12 mins).
# TREE (3) (took: 0.03 mins).
# TREE (4) (took: 0.03 mins).
# TREE (5) (took: 0.02 mins).
# TREE (6) (took: 0.03 mins).
# TREE (7) (took: 0.17 mins).
#
# TRAINING FINISHED!
#
# TRAINING TOOK: 0.52 mins.
# **********************************************************
#
#
#     **********************************************************
#                        RANDOM FOREST MODEL
#
#       ------------------ Hyperparameters -------------------
#         num_trees -> 8
#         sample_size -> 1
#         replace -> False
#         splitting_rule -> gini
#         max_depth -> 5
#         min_bucket -> 1
#         mtry -> 6
#         alpha -> 1
#         handle_outliers -> False
#         weight_classes -> False
#         uniform_strength -> 0
#       ------------------------------------------------------
#
#     **********************************************************
#
# **********************************************************
# TRAINING STARTED...
#
# TREE (0) (took: 0.98 mins).
# TREE (1) (took: 1.07 mins).
# TREE (2) (took: 1.55 mins).
# TREE (3) (took: 1.3 mins).
# TREE (4) (took: 1.07 mins).
# TREE (5) (took: 0.7 mins).
# TREE (6) (took: 1.35 mins).
# TREE (7) (took: 1.25 mins).
#
# TRAINING FINISHED!
#
# TRAINING TOOK: 9.27 mins.
# **********************************************************
#
#
#     **********************************************************
#                        RANDOM FOREST MODEL
#
#       ------------------ Hyperparameters -------------------
#         num_trees -> 9
#         sample_size -> 1
#         replace -> False
#         splitting_rule -> gini
#         max_depth -> 5
#         min_bucket -> 1
#         mtry -> 6
#         alpha -> 0.01
#         handle_outliers -> False
#         weight_classes -> False
#         uniform_strength -> 0
#       ------------------------------------------------------
#
#     **********************************************************
#
# **********************************************************
# TRAINING STARTED...
#
# TREE (0) (took: 0.02 mins).
# TREE (1) (took: 0.02 mins).
# TREE (2) (took: 0.02 mins).
# TREE (3) (took: 0.0 mins).
# TREE (4) (took: 0.0 mins).
# TREE (5) (took: 0.02 mins).
# TREE (6) (took: 0.02 mins).
# TREE (7) (took: 0.02 mins).
# TREE (8) (took: 0.02 mins).
#
# TRAINING FINISHED!
#
# TRAINING TOOK: 0.12 mins.
# **********************************************************
#     **********************************************************
#                        RANDOM FOREST MODEL
#
#       ------------------ Hyperparameters -------------------
#         num_trees -> 9
#         sample_size -> 1
#         replace -> False
#         splitting_rule -> gini
#         max_depth -> 5
#         min_bucket -> 1
#         mtry -> 6
#         alpha -> 0.05
#         handle_outliers -> False
#         weight_classes -> False
#         uniform_strength -> 0
#       ------------------------------------------------------
#
#     **********************************************************
#
# **********************************************************
# TRAINING STARTED...
#
# TREE (0) (took: 0.02 mins).
# TREE (1) (took: 0.02 mins).
# TREE (2) (took: 0.1 mins).
# TREE (3) (took: 0.02 mins).
# TREE (4) (took: 0.02 mins).
# TREE (5) (took: 0.02 mins).
# TREE (6) (took: 0.02 mins).
# TREE (7) (took: 0.02 mins).
# TREE (8) (took: 0.02 mins).
#
# TRAINING FINISHED!
#
# TRAINING TOOK: 0.23 mins.
# **********************************************************
#
#
#     **********************************************************
#                        RANDOM FOREST MODEL
#
#       ------------------ Hyperparameters -------------------
#         num_trees -> 9
#         sample_size -> 1
#         replace -> False
#         splitting_rule -> gini
#         max_depth -> 5
#         min_bucket -> 1
#         mtry -> 6
#         alpha -> 0.1
#         handle_outliers -> False
#         weight_classes -> False
#         uniform_strength -> 0
#       ------------------------------------------------------
#
#     **********************************************************
#
# **********************************************************
# TRAINING STARTED...
#
# TREE (0) (took: 0.08 mins).
# TREE (1) (took: 0.03 mins).
# TREE (2) (took: 0.02 mins).
# TREE (3) (took: 0.02 mins).
# TREE (4) (took: 0.02 mins).
# TREE (5) (took: 0.02 mins).
# TREE (6) (took: 0.02 mins).
# TREE (7) (took: 0.02 mins).
# TREE (8) (took: 0.02 mins).
#
# TRAINING FINISHED!
#
# TRAINING TOOK: 0.23 mins.
# **********************************************************
#
#
#     **********************************************************
#                        RANDOM FOREST MODEL
#
#       ------------------ Hyperparameters -------------------
#         num_trees -> 9
#         sample_size -> 1
#         replace -> False
#         splitting_rule -> gini
#         max_depth -> 5
#         min_bucket -> 1
#         mtry -> 6
#         alpha -> 1
#         handle_outliers -> False
#         weight_classes -> False
#         uniform_strength -> 0
#       ------------------------------------------------------
#
#     **********************************************************
#
# **********************************************************
# TRAINING STARTED...
#
# TREE (0) (took: 1.3 mins).
# TREE (1) (took: 1.18 mins).
# TREE (2) (took: 1.03 mins).
# TREE (3) (took: 1.37 mins).
# TREE (4) (took: 0.97 mins).
# TREE (5) (took: 1.43 mins).
# TREE (6) (took: 1.33 mins).
# TREE (7) (took: 1.08 mins).
# TREE (8) (took: 1.28 mins).
#
# TRAINING FINISHED!
#
# TRAINING TOOK: 10.98 mins.
# **********************************************************
#
#
#     **********************************************************
#                        RANDOM FOREST MODEL
#
#       ------------------ Hyperparameters -------------------
#         num_trees -> 10
#         sample_size -> 1
#         replace -> False
#         splitting_rule -> gini
#         max_depth -> 5
#         min_bucket -> 1
#         mtry -> 6
#         alpha -> 0.01
#         handle_outliers -> False
#         weight_classes -> False
#         uniform_strength -> 0
#       ------------------------------------------------------
#
#     **********************************************************
#
# **********************************************************
# TRAINING STARTED...
#
# TREE (0) (took: 0.0 mins).
# TREE (1) (took: 0.0 mins).
# TREE (2) (took: 0.0 mins).
# TREE (3) (took: 0.02 mins).
# TREE (4) (took: 0.02 mins).
# TREE (5) (took: 0.02 mins).
# TREE (6) (took: 0.02 mins).
# TREE (7) (took: 0.02 mins).
# TREE (8) (took: 0.0 mins).
# TREE (9) (took: 0.02 mins).
#
# TRAINING FINISHED!
#
# TRAINING TOOK: 0.1 mins.
# **********************************************************
#
#
#     **********************************************************
#                        RANDOM FOREST MODEL
#
#       ------------------ Hyperparameters -------------------
#         num_trees -> 10
#         sample_size -> 1
#         replace -> False
#         splitting_rule -> gini
#         max_depth -> 5
#         min_bucket -> 1
#         mtry -> 6
#         alpha -> 0.05
#         handle_outliers -> False
#         weight_classes -> False
#         uniform_strength -> 0
#       ------------------------------------------------------
#
#     **********************************************************
#
# **********************************************************
# TRAINING STARTED...
#
# TREE (0) (took: 0.02 mins).
# TREE (1) (took: 0.03 mins).
# TREE (2) (took: 0.02 mins).
# TREE (3) (took: 0.07 mins).
# TREE (4) (took: 0.02 mins).
# TREE (5) (took: 0.02 mins).
# TREE (6) (took: 0.02 mins).
# TREE (7) (took: 0.0 mins).
# TREE (8) (took: 0.02 mins).
# TREE (9) (took: 0.02 mins).
#
# TRAINING FINISHED!
#
# TRAINING TOOK: 0.22 mins.
# **********************************************************
#
#
#     **********************************************************
#                        RANDOM FOREST MODEL
#
#       ------------------ Hyperparameters -------------------
#         num_trees -> 10
#         sample_size -> 1
#         replace -> False
#         splitting_rule -> gini
#         max_depth -> 5
#         min_bucket -> 1
#         mtry -> 6
#         alpha -> 0.1
#         handle_outliers -> False
#         weight_classes -> False
#         uniform_strength -> 0
#       ------------------------------------------------------
#
#     **********************************************************
#
# **********************************************************
# TRAINING STARTED...
#
# TREE (0) (took: 0.02 mins).
# TREE (1) (took: 0.17 mins).
# TREE (2) (took: 0.03 mins).
# TREE (3) (took: 0.02 mins).
# TREE (4) (took: 0.02 mins).
# TREE (5) (took: 0.02 mins).
# TREE (6) (took: 0.22 mins).
# TREE (7) (took: 0.15 mins).
# TREE (8) (took: 0.02 mins).
# TREE (9) (took: 0.02 mins).
#
# TRAINING FINISHED!
#
# TRAINING TOOK: 0.67 mins.
# **********************************************************
#
#
#     **********************************************************
#                        RANDOM FOREST MODEL
#
#       ------------------ Hyperparameters -------------------
#         num_trees -> 10
#         sample_size -> 1
#         replace -> False
#         splitting_rule -> gini
#         max_depth -> 5
#         min_bucket -> 1
#         mtry -> 6
#         alpha -> 1
#         handle_outliers -> False
#         weight_classes -> False
#         uniform_strength -> 0
#       ------------------------------------------------------
#
#     **********************************************************
#
# **********************************************************
# TRAINING STARTED...
# TREE (0) (took: 1.07 mins).
# TREE (1) (took: 1.53 mins).
# TREE (2) (took: 1.13 mins).
# TREE (3) (took: 1.07 mins).
# TREE (4) (took: 1.27 mins).
# TREE (5) (took: 1.55 mins).
# TREE (6) (took: 1.05 mins).
# TREE (7) (took: 1.53 mins).
# TREE (8) (took: 1.15 mins).
# TREE (9) (took: 1.27 mins).
#
# TRAINING FINISHED!
#
# TRAINING TOOK: 12.62 mins.
# **********************************************************
#
# 								*** RECALL -> TRAIN SET ***
# 								*** RECALL -> TEST SET ***
# 								<<<<<<<< RUN 1 >>>>>>>>
#
#     **********************************************************
#                        RANDOM FOREST MODEL
#
#       ------------------ Hyperparameters -------------------
#         num_trees -> 6
#         sample_size -> 1
#         replace -> False
#         splitting_rule -> gini
#         max_depth -> 5
#         min_bucket -> 1
#         mtry -> 6
#         alpha -> 0.01
#         handle_outliers -> False
#         weight_classes -> False
#         uniform_strength -> 0
#       ------------------------------------------------------
#
#     **********************************************************
#
# **********************************************************
# TRAINING STARTED...
#
# TREE (0) (took: 0.02 mins).
# TREE (1) (took: 0.02 mins).
# TREE (2) (took: 0.02 mins).
# TREE (3) (took: 0.02 mins).
# TREE (4) (took: 0.02 mins).
# TREE (5) (took: 0.0 mins).
#
# TRAINING FINISHED!
#
# TRAINING TOOK: 0.08 mins.
# **********************************************************
#
#
#     **********************************************************
#                        RANDOM FOREST MODEL
#
#       ------------------ Hyperparameters -------------------
#         num_trees -> 6
#         sample_size -> 1
#         replace -> False
#         splitting_rule -> gini
#         max_depth -> 5
#         min_bucket -> 1
#         mtry -> 6
#         alpha -> 0.05
#         handle_outliers -> False
#         weight_classes -> False
#         uniform_strength -> 0
#       ------------------------------------------------------
#
#     **********************************************************
#
# **********************************************************
# TRAINING STARTED...
#
# TREE (0) (took: 0.02 mins).
# TREE (1) (took: 0.02 mins).
# TREE (2) (took: 0.02 mins).
# TREE (3) (took: 0.08 mins).
# TREE (4) (took: 0.02 mins).
# TREE (5) (took: 0.02 mins).
#
# TRAINING FINISHED!
#
# TRAINING TOOK: 0.17 mins.
# **********************************************************
#
#
#     **********************************************************
#                        RANDOM FOREST MODEL
#
#       ------------------ Hyperparameters -------------------
#         num_trees -> 6
#         sample_size -> 1
#         replace -> False
#         splitting_rule -> gini
#         max_depth -> 5
#         min_bucket -> 1
#         mtry -> 6
#         alpha -> 0.1
#         handle_outliers -> False
#         weight_classes -> False
#         uniform_strength -> 0
#       ------------------------------------------------------
#
#     **********************************************************
#
# **********************************************************
# TRAINING STARTED...
#
# TREE (0) (took: 0.02 mins).
# TREE (1) (took: 0.02 mins).
# TREE (2) (took: 0.03 mins).
# TREE (3) (took: 0.02 mins).
# TREE (4) (took: 0.02 mins).
# TREE (5) (took: 0.0 mins).
#
# TRAINING FINISHED!
#
# TRAINING TOOK: 0.1 mins.
# **********************************************************
#
#
#     **********************************************************
#                        RANDOM FOREST MODEL
#
#       ------------------ Hyperparameters -------------------
#         num_trees -> 6
#         sample_size -> 1
#         replace -> False
#         splitting_rule -> gini
#         max_depth -> 5
#         min_bucket -> 1
#         mtry -> 6
#         alpha -> 1
#         handle_outliers -> False
#         weight_classes -> False
#         uniform_strength -> 0
#       ------------------------------------------------------
#
#     **********************************************************
#
# **********************************************************
# TRAINING STARTED...
#
# TREE (0) (took: 1.0 mins).
# TREE (1) (took: 1.62 mins).
# TREE (2) (took: 1.53 mins).
# TREE (3) (took: 1.43 mins).
# TREE (4) (took: 1.15 mins).
# TREE (5) (took: 1.2 mins).
#
# TRAINING FINISHED!
#
# TRAINING TOOK: 7.93 mins.
# **********************************************************
#
#
#     **********************************************************
#                        RANDOM FOREST MODEL
#
#       ------------------ Hyperparameters -------------------
#         num_trees -> 7
#         sample_size -> 1
#         replace -> False
#         splitting_rule -> gini
#         max_depth -> 5
#         min_bucket -> 1
#         mtry -> 6
#         alpha -> 0.01
#         handle_outliers -> False
#         weight_classes -> False
#         uniform_strength -> 0
#       ------------------------------------------------------
#
#     **********************************************************
#
# **********************************************************
# TRAINING STARTED...
#
# TREE (0) (took: 0.02 mins).
# TREE (1) (took: 0.02 mins).
# TREE (2) (took: 0.02 mins).
# TREE (3) (took: 0.03 mins).
# TREE (4) (took: 0.0 mins).
# TREE (5) (took: 0.02 mins).
# TREE (6) (took: 0.02 mins).
#
# TRAINING FINISHED!
#
# TRAINING TOOK: 0.12 mins.
# **********************************************************
#
#
#     **********************************************************
#                        RANDOM FOREST MODEL
#
#       ------------------ Hyperparameters -------------------
#         num_trees -> 7
#         sample_size -> 1
#         replace -> False
#         splitting_rule -> gini
#         max_depth -> 5
#         min_bucket -> 1
#         mtry -> 6
#         alpha -> 0.05
#         handle_outliers -> False
#         weight_classes -> False
#         uniform_strength -> 0
#       ------------------------------------------------------
#
#     **********************************************************
#
# **********************************************************
# TRAINING STARTED...
#
# TREE (0) (took: 0.08 mins).
# TREE (1) (took: 0.02 mins).
# TREE (2) (took: 0.0 mins).
# TREE (3) (took: 0.02 mins).
# TREE (4) (took: 0.02 mins).
# TREE (5) (took: 0.02 mins).
# TREE (6) (took: 0.02 mins).
#
# TRAINING FINISHED!
#
# TRAINING TOOK: 0.17 mins.
# **********************************************************
#
#
#     **********************************************************
#                        RANDOM FOREST MODEL
#
#       ------------------ Hyperparameters -------------------
#         num_trees -> 7
#         sample_size -> 1
#         replace -> False
#         splitting_rule -> gini
#         max_depth -> 5
#         min_bucket -> 1
#         mtry -> 6
#         alpha -> 0.1
#         handle_outliers -> False
#         weight_classes -> False
#         uniform_strength -> 0
#       ------------------------------------------------------
#
#     **********************************************************
#
# **********************************************************
# TRAINING STARTED...
# TREE (0) (took: 0.03 mins).
# TREE (1) (took: 0.02 mins).
# TREE (2) (took: 0.02 mins).
# TREE (3) (took: 0.1 mins).
# TREE (4) (took: 0.03 mins).
# TREE (5) (took: 0.18 mins).
# TREE (6) (took: 0.03 mins).
#
# TRAINING FINISHED!
#
# TRAINING TOOK: 0.42 mins.
# **********************************************************
#
#
#     **********************************************************
#                        RANDOM FOREST MODEL
#
#       ------------------ Hyperparameters -------------------
#         num_trees -> 7
#         sample_size -> 1
#         replace -> False
#         splitting_rule -> gini
#         max_depth -> 5
#         min_bucket -> 1
#         mtry -> 6
#         alpha -> 1
#         handle_outliers -> False
#         weight_classes -> False
#         uniform_strength -> 0
#       ------------------------------------------------------
#
#     **********************************************************
#
# **********************************************************
# TRAINING STARTED...
#
# TREE (0) (took: 2.43 mins).
# TREE (1) (took: 2.1 mins).
# TREE (2) (took: 2.33 mins).
# TREE (3) (took: 1.4 mins).
# TREE (4) (took: 1.37 mins).
# TREE (5) (took: 1.4 mins).
# TREE (6) (took: 1.42 mins).
#
# TRAINING FINISHED!
#
# TRAINING TOOK: 12.45 mins.
# **********************************************************
#
#
#     **********************************************************
#                        RANDOM FOREST MODEL
#
#       ------------------ Hyperparameters -------------------
#         num_trees -> 8
#         sample_size -> 1
#         replace -> False
#         splitting_rule -> gini
#         max_depth -> 5
#         min_bucket -> 1
#         mtry -> 6
#         alpha -> 0.01
#         handle_outliers -> False
#         weight_classes -> False
#         uniform_strength -> 0
#       ------------------------------------------------------
#
#     **********************************************************
#
# **********************************************************
# TRAINING STARTED...
#
# TREE (0) (took: 0.02 mins).
# TREE (1) (took: 0.02 mins).
# TREE (2) (took: 0.0 mins).
# TREE (3) (took: 0.0 mins).
# TREE (4) (took: 0.02 mins).
# TREE (5) (took: 0.02 mins).
# TREE (6) (took: 0.02 mins).
# TREE (7) (took: 0.02 mins).
#
# TRAINING FINISHED!
#
# TRAINING TOOK: 0.1 mins.
# **********************************************************
#
#
#     **********************************************************
#                        RANDOM FOREST MODEL
#
#       ------------------ Hyperparameters -------------------
#         num_trees -> 8
#         sample_size -> 1
#         replace -> False
#         splitting_rule -> gini
#         max_depth -> 5
#         min_bucket -> 1
#         mtry -> 6
#         alpha -> 0.05
#         handle_outliers -> False
#         weight_classes -> False
#         uniform_strength -> 0
#       ------------------------------------------------------
#
#     **********************************************************
#
# **********************************************************
# TRAINING STARTED...
#
# TREE (0) (took: 0.03 mins).
# TREE (1) (took: 0.03 mins).
# TREE (2) (took: 0.02 mins).
# TREE (3) (took: 0.02 mins).
# TREE (4) (took: 0.03 mins).
# TREE (5) (took: 0.02 mins).
# TREE (6) (took: 0.02 mins).
# TREE (7) (took: 0.02 mins).
#
# TRAINING FINISHED!
#
# TRAINING TOOK: 0.18 mins.
# **********************************************************
#
#
#     **********************************************************
#                        RANDOM FOREST MODEL
#
#       ------------------ Hyperparameters -------------------
#         num_trees -> 8
#         sample_size -> 1
#         replace -> False
#         splitting_rule -> gini
#         max_depth -> 5
#         min_bucket -> 1
#         mtry -> 6
#         alpha -> 0.1
#         handle_outliers -> False
#         weight_classes -> False
#         uniform_strength -> 0
#       ------------------------------------------------------
#
#     **********************************************************
#
# **********************************************************
# TRAINING STARTED...
#
# TREE (0) (took: 0.02 mins).
# TREE (1) (took: 0.02 mins).
# TREE (2) (took: 0.02 mins).
# TREE (3) (took: 0.02 mins).
# TREE (4) (took: 0.02 mins).
# TREE (5) (took: 0.0 mins).
# TREE (6) (took: 0.02 mins).
# TREE (7) (took: 0.1 mins).
#
# TRAINING FINISHED!
#
# TRAINING TOOK: 0.2 mins.
# **********************************************************
#
#
#     **********************************************************
#                        RANDOM FOREST MODEL
#
#       ------------------ Hyperparameters -------------------
#         num_trees -> 8
#         sample_size -> 1
#         replace -> False
#         splitting_rule -> gini
#         max_depth -> 5
#         min_bucket -> 1
#         mtry -> 6
#         alpha -> 1
#         handle_outliers -> False
#         weight_classes -> False
#         uniform_strength -> 0
#       ------------------------------------------------------
#
#     **********************************************************
#
# **********************************************************
# TRAINING STARTED...
#
# TREE (0) (took: 1.27 mins).
# TREE (1) (took: 1.13 mins).
# TREE (2) (took: 1.53 mins).
# TREE (3) (took: 1.38 mins).
# TREE (4) (took: 1.62 mins).
# TREE (5) (took: 1.2 mins).
# TREE (6) (took: 1.23 mins).
# TREE (7) (took: 0.85 mins).
#
# TRAINING FINISHED!
#
# TRAINING TOOK: 10.22 mins.
# **********************************************************
#
#
#     **********************************************************
#                        RANDOM FOREST MODEL
#
#       ------------------ Hyperparameters -------------------
#         num_trees -> 9
#         sample_size -> 1
#         replace -> False
#         splitting_rule -> gini
#         max_depth -> 5
#         min_bucket -> 1
#         mtry -> 6
#         alpha -> 0.01
#         handle_outliers -> False
#         weight_classes -> False
#         uniform_strength -> 0
#       ------------------------------------------------------
#
#     **********************************************************
#
# **********************************************************
# TRAINING STARTED...
#
# TREE (0) (took: 0.02 mins).
# TREE (1) (took: 0.0 mins).
# TREE (2) (took: 0.02 mins).
# TREE (3) (took: 0.02 mins).
# TREE (4) (took: 0.02 mins).
# TREE (5) (took: 0.02 mins).
# TREE (6) (took: 0.02 mins).
# TREE (7) (took: 0.02 mins).
# TREE (8) (took: 0.0 mins).
#
# TRAINING FINISHED!
#
# TRAINING TOOK: 0.12 mins.
# **********************************************************
#     **********************************************************
#                        RANDOM FOREST MODEL
#
#       ------------------ Hyperparameters -------------------
#         num_trees -> 9
#         sample_size -> 1
#         replace -> False
#         splitting_rule -> gini
#         max_depth -> 5
#         min_bucket -> 1
#         mtry -> 6
#         alpha -> 0.05
#         handle_outliers -> False
#         weight_classes -> False
#         uniform_strength -> 0
#       ------------------------------------------------------
#
#     **********************************************************
#
# **********************************************************
# TRAINING STARTED...
#
# TREE (0) (took: 0.02 mins).
# TREE (1) (took: 0.02 mins).
# TREE (2) (took: 0.02 mins).
# TREE (3) (took: 0.02 mins).
# TREE (4) (took: 0.03 mins).
# TREE (5) (took: 0.02 mins).
# TREE (6) (took: 0.02 mins).
# TREE (7) (took: 0.02 mins).
# TREE (8) (took: 0.02 mins).
#
# TRAINING FINISHED!
#
# TRAINING TOOK: 0.17 mins.
# **********************************************************
#
#
#     **********************************************************
#                        RANDOM FOREST MODEL
#
#       ------------------ Hyperparameters -------------------
#         num_trees -> 9
#         sample_size -> 1
#         replace -> False
#         splitting_rule -> gini
#         max_depth -> 5
#         min_bucket -> 1
#         mtry -> 6
#         alpha -> 0.1
#         handle_outliers -> False
#         weight_classes -> False
#         uniform_strength -> 0
#       ------------------------------------------------------
#
#     **********************************************************
#
# **********************************************************
# TRAINING STARTED...
#
# TREE (0) (took: 0.02 mins).
# TREE (1) (took: 0.02 mins).
# TREE (2) (took: 0.02 mins).
# TREE (3) (took: 0.1 mins).
# TREE (4) (took: 0.02 mins).
# TREE (5) (took: 0.02 mins).
# TREE (6) (took: 0.02 mins).
# TREE (7) (took: 0.15 mins).
# TREE (8) (took: 0.0 mins).
#
# TRAINING FINISHED!
#
# TRAINING TOOK: 0.35 mins.
# **********************************************************
#
#
#     **********************************************************
#                        RANDOM FOREST MODEL
#
#       ------------------ Hyperparameters -------------------
#         num_trees -> 9
#         sample_size -> 1
#         replace -> False
#         splitting_rule -> gini
#         max_depth -> 5
#         min_bucket -> 1
#         mtry -> 6
#         alpha -> 1
#         handle_outliers -> False
#         weight_classes -> False
#         uniform_strength -> 0
#       ------------------------------------------------------
#
#     **********************************************************
#
# **********************************************************
# TRAINING STARTED...
#
# TREE (0) (took: 1.63 mins).
# TREE (1) (took: 1.15 mins).
# TREE (2) (took: 1.42 mins).
# TREE (3) (took: 1.37 mins).
# TREE (4) (took: 1.18 mins).
# TREE (5) (took: 1.5 mins).
# TREE (6) (took: 1.68 mins).
# TREE (7) (took: 1.38 mins).
# TREE (8) (took: 1.62 mins).
#
# TRAINING FINISHED!
#
# TRAINING TOOK: 12.93 mins.
# **********************************************************
#
#
#     **********************************************************
#                        RANDOM FOREST MODEL
#
#       ------------------ Hyperparameters -------------------
#         num_trees -> 10
#         sample_size -> 1
#         replace -> False
#         splitting_rule -> gini
#         max_depth -> 5
#         min_bucket -> 1
#         mtry -> 6
#         alpha -> 0.01
#         handle_outliers -> False
#         weight_classes -> False
#         uniform_strength -> 0
#       ------------------------------------------------------
#
#     **********************************************************
#
# **********************************************************
# TRAINING STARTED...
#
# TREE (0) (took: 0.02 mins).
# TREE (1) (took: 0.03 mins).
# TREE (2) (took: 0.05 mins).
# TREE (3) (took: 0.03 mins).
# TREE (4) (took: 0.02 mins).
# TREE (5) (took: 0.0 mins).
# TREE (6) (took: 0.02 mins).
# TREE (7) (took: 0.02 mins).
# TREE (8) (took: 0.0 mins).
# TREE (9) (took: 0.0 mins).
#
# TRAINING FINISHED!
#
# TRAINING TOOK: 0.18 mins.
# **********************************************************
#
#
#     **********************************************************
#                        RANDOM FOREST MODEL
#
#       ------------------ Hyperparameters -------------------
#         num_trees -> 10
#         sample_size -> 1
#         replace -> False
#         splitting_rule -> gini
#         max_depth -> 5
#         min_bucket -> 1
#         mtry -> 6
#         alpha -> 0.05
#         handle_outliers -> False
#         weight_classes -> False
#         uniform_strength -> 0
#       ------------------------------------------------------
#
#     **********************************************************
#
# **********************************************************
# TRAINING STARTED...
#
# TREE (0) (took: 0.02 mins).
# TREE (1) (took: 0.02 mins).
# TREE (2) (took: 0.02 mins).
# TREE (3) (took: 0.02 mins).
# TREE (4) (took: 0.02 mins).
# TREE (5) (took: 0.03 mins).
# TREE (6) (took: 0.02 mins).
# TREE (7) (took: 0.02 mins).
# TREE (8) (took: 0.0 mins).
# TREE (9) (took: 0.02 mins).
#
# TRAINING FINISHED!
#
# TRAINING TOOK: 0.17 mins.
# **********************************************************
#
#
#     **********************************************************
#                        RANDOM FOREST MODEL
#
#       ------------------ Hyperparameters -------------------
#         num_trees -> 10
#         sample_size -> 1
#         replace -> False
#         splitting_rule -> gini
#         max_depth -> 5
#         min_bucket -> 1
#         mtry -> 6
#         alpha -> 0.1
#         handle_outliers -> False
#         weight_classes -> False
#         uniform_strength -> 0
#       ------------------------------------------------------
#
#     **********************************************************
#
# **********************************************************
# TRAINING STARTED...
#
# TREE (0) (took: 0.05 mins).
# TREE (1) (took: 0.02 mins).
# TREE (2) (took: 0.03 mins).
# TREE (3) (took: 0.02 mins).
# TREE (4) (took: 0.02 mins).
# TREE (5) (took: 0.02 mins).
# TREE (6) (took: 0.02 mins).
# TREE (7) (took: 0.02 mins).
# TREE (8) (took: 0.02 mins).
# TREE (9) (took: 0.02 mins).
#
# TRAINING FINISHED!
#
# TRAINING TOOK: 0.22 mins.
# **********************************************************
#
#
#     **********************************************************
#                        RANDOM FOREST MODEL
#
#       ------------------ Hyperparameters -------------------
#         num_trees -> 10
#         sample_size -> 1
#         replace -> False
#         splitting_rule -> gini
#         max_depth -> 5
#         min_bucket -> 1
#         mtry -> 6
#         alpha -> 1
#         handle_outliers -> False
#         weight_classes -> False
#         uniform_strength -> 0
#       ------------------------------------------------------
#
#     **********************************************************
#
# **********************************************************
# TRAINING STARTED...
# TREE (0) (took: 1.25 mins).
# TREE (1) (took: 1.1 mins).
# TREE (2) (took: 1.27 mins).
# TREE (3) (took: 1.28 mins).
# TREE (4) (took: 1.25 mins).
# TREE (5) (took: 1.25 mins).
# TREE (6) (took: 1.15 mins).
# TREE (7) (took: 1.38 mins).
# TREE (8) (took: 1.07 mins).
# TREE (9) (took: 1.17 mins).
#
# TRAINING FINISHED!
#
# TRAINING TOOK: 12.17 mins.
# **********************************************************
#
# 								*** RECALL -> TRAIN SET ***
# 								*** RECALL -> TEST SET ***
# 								<<<<<<<< RUN 2 >>>>>>>>
#
#     **********************************************************
#                        RANDOM FOREST MODEL
#
#       ------------------ Hyperparameters -------------------
#         num_trees -> 6
#         sample_size -> 1
#         replace -> False
#         splitting_rule -> gini
#         max_depth -> 5
#         min_bucket -> 1
#         mtry -> 6
#         alpha -> 0.01
#         handle_outliers -> False
#         weight_classes -> False
#         uniform_strength -> 0
#       ------------------------------------------------------
#
#     **********************************************************
#
# **********************************************************
# TRAINING STARTED...
#
# TREE (0) (took: 0.0 mins).
# TREE (1) (took: 0.02 mins).
# TREE (2) (took: 0.02 mins).
# TREE (3) (took: 0.0 mins).
# TREE (4) (took: 0.0 mins).
# TREE (5) (took: 0.0 mins).
#
# TRAINING FINISHED!
#
# TRAINING TOOK: 0.03 mins.
# **********************************************************
#
#
#     **********************************************************
#                        RANDOM FOREST MODEL
#
#       ------------------ Hyperparameters -------------------
#         num_trees -> 6
#         sample_size -> 1
#         replace -> False
#         splitting_rule -> gini
#         max_depth -> 5
#         min_bucket -> 1
#         mtry -> 6
#         alpha -> 0.05
#         handle_outliers -> False
#         weight_classes -> False
#         uniform_strength -> 0
#       ------------------------------------------------------
#
#     **********************************************************
#
# **********************************************************
# TRAINING STARTED...
#
# TREE (0) (took: 0.02 mins).
# TREE (1) (took: 0.0 mins).
# TREE (2) (took: 0.02 mins).
# TREE (3) (took: 0.02 mins).
# TREE (4) (took: 0.02 mins).
# TREE (5) (took: 0.02 mins).
#
# TRAINING FINISHED!
#
# TRAINING TOOK: 0.08 mins.
# **********************************************************
#
#
#     **********************************************************
#                        RANDOM FOREST MODEL
#
#       ------------------ Hyperparameters -------------------
#         num_trees -> 6
#         sample_size -> 1
#         replace -> False
#         splitting_rule -> gini
#         max_depth -> 5
#         min_bucket -> 1
#         mtry -> 6
#         alpha -> 0.1
#         handle_outliers -> False
#         weight_classes -> False
#         uniform_strength -> 0
#       ------------------------------------------------------
#
#     **********************************************************
#
# **********************************************************
# TRAINING STARTED...
#
# TREE (0) (took: 0.03 mins).
# TREE (1) (took: 0.02 mins).
# TREE (2) (took: 0.08 mins).
# TREE (3) (took: 0.07 mins).
# TREE (4) (took: 0.02 mins).
# TREE (5) (took: 0.07 mins).
#
# TRAINING FINISHED!
#
# TRAINING TOOK: 0.28 mins.
# **********************************************************
#
#
#     **********************************************************
#                        RANDOM FOREST MODEL
#
#       ------------------ Hyperparameters -------------------
#         num_trees -> 6
#         sample_size -> 1
#         replace -> False
#         splitting_rule -> gini
#         max_depth -> 5
#         min_bucket -> 1
#         mtry -> 6
#         alpha -> 1
#         handle_outliers -> False
#         weight_classes -> False
#         uniform_strength -> 0
#       ------------------------------------------------------
#
#     **********************************************************
#
# **********************************************************
# TRAINING STARTED...
#
# TREE (0) (took: 1.43 mins).
# TREE (1) (took: 1.12 mins).
# TREE (2) (took: 1.4 mins).
# TREE (3) (took: 1.13 mins).
# TREE (4) (took: 1.07 mins).
# TREE (5) (took: 1.02 mins).
#
# TRAINING FINISHED!
#
# TRAINING TOOK: 7.17 mins.
# **********************************************************
#
#
#     **********************************************************
#                        RANDOM FOREST MODEL
#
#       ------------------ Hyperparameters -------------------
#         num_trees -> 7
#         sample_size -> 1
#         replace -> False
#         splitting_rule -> gini
#         max_depth -> 5
#         min_bucket -> 1
#         mtry -> 6
#         alpha -> 0.01
#         handle_outliers -> False
#         weight_classes -> False
#         uniform_strength -> 0
#       ------------------------------------------------------
#
#     **********************************************************
#
# **********************************************************
# TRAINING STARTED...
#
# TREE (0) (took: 0.0 mins).
# TREE (1) (took: 0.02 mins).
# TREE (2) (took: 0.02 mins).
# TREE (3) (took: 0.0 mins).
# TREE (4) (took: 0.0 mins).
# TREE (5) (took: 0.0 mins).
# TREE (6) (took: 0.0 mins).
#
# TRAINING FINISHED!
#
# TRAINING TOOK: 0.03 mins.
# **********************************************************
#
#
#     **********************************************************
#                        RANDOM FOREST MODEL
#
#       ------------------ Hyperparameters -------------------
#         num_trees -> 7
#         sample_size -> 1
#         replace -> False
#         splitting_rule -> gini
#         max_depth -> 5
#         min_bucket -> 1
#         mtry -> 6
#         alpha -> 0.05
#         handle_outliers -> False
#         weight_classes -> False
#         uniform_strength -> 0
#       ------------------------------------------------------
#
#     **********************************************************
#
# **********************************************************
# TRAINING STARTED...
#
# TREE (0) (took: 0.02 mins).
# TREE (1) (took: 0.0 mins).
# TREE (2) (took: 0.02 mins).
# TREE (3) (took: 0.03 mins).
# TREE (4) (took: 0.03 mins).
# TREE (5) (took: 0.0 mins).
# TREE (6) (took: 0.02 mins).
#
# TRAINING FINISHED!
#
# TRAINING TOOK: 0.12 mins.
# **********************************************************
#
#
#     **********************************************************
#                        RANDOM FOREST MODEL
#
#       ------------------ Hyperparameters -------------------
#         num_trees -> 7
#         sample_size -> 1
#         replace -> False
#         splitting_rule -> gini
#         max_depth -> 5
#         min_bucket -> 1
#         mtry -> 6
#         alpha -> 0.1
#         handle_outliers -> False
#         weight_classes -> False
#         uniform_strength -> 0
#       ------------------------------------------------------
#
#     **********************************************************
#
# **********************************************************
# TRAINING STARTED...
# TREE (0) (took: 0.02 mins).
# TREE (1) (took: 0.03 mins).
# TREE (2) (took: 0.02 mins).
# TREE (3) (took: 0.02 mins).
# TREE (4) (took: 0.02 mins).
# TREE (5) (took: 0.02 mins).
# TREE (6) (took: 0.02 mins).
#
# TRAINING FINISHED!
#
# TRAINING TOOK: 0.13 mins.
# **********************************************************
#
#
#     **********************************************************
#                        RANDOM FOREST MODEL
#
#       ------------------ Hyperparameters -------------------
#         num_trees -> 7
#         sample_size -> 1
#         replace -> False
#         splitting_rule -> gini
#         max_depth -> 5
#         min_bucket -> 1
#         mtry -> 6
#         alpha -> 1
#         handle_outliers -> False
#         weight_classes -> False
#         uniform_strength -> 0
#       ------------------------------------------------------
#
#     **********************************************************
#
# **********************************************************
# TRAINING STARTED...
#
# TREE (0) (took: 1.35 mins).
# TREE (1) (took: 1.3 mins).
# TREE (2) (took: 0.93 mins).
# TREE (3) (took: 1.0 mins).
# ...
#
#     **********************************************************
#
# **********************************************************
# TRAINING STARTED...
#
# TREE (0) (took: 0.0 mins).
# TREE (1) (took: 0.02 mins).
# TREE (2) (took: 0.0 mins).
# TREE (3) (took: 0.0 mins).
# TREE (4) (took: 0.0 mins).
# TREE (5) (took: 0.02 mins).
# TREE (6) (took: 0.02 mins).
#
# TRAINING FINISHED!
#
# TRAINING TOOK: 0.05 mins.
# **********************************************************
#
#
#     **********************************************************
#                        RANDOM FOREST MODEL
#
#       ------------------ Hyperparameters -------------------
#         num_trees -> 7
#         sample_size -> 1
#         replace -> False
#         splitting_rule -> gini
#         max_depth -> 5
#         min_bucket -> 1
#         mtry -> 6
#         alpha -> 0.05
#         handle_outliers -> False
#         weight_classes -> False
#         uniform_strength -> 0
#       ------------------------------------------------------
#
#     **********************************************************
#
# **********************************************************
# TRAINING STARTED...
#
# TREE (0) (took: 0.02 mins).
# TREE (1) (took: 0.02 mins).
# TREE (2) (took: 0.02 mins).
# TREE (3) (took: 0.02 mins).
# TREE (4) (took: 0.0 mins).
# TREE (5) (took: 0.02 mins).
# TREE (6) (took: 0.08 mins).
#
# TRAINING FINISHED!
#
# TRAINING TOOK: 0.17 mins.
# **********************************************************
#
#
#     **********************************************************
#                        RANDOM FOREST MODEL
#
#       ------------------ Hyperparameters -------------------
#         num_trees -> 7
#         sample_size -> 1
#         replace -> False
#         splitting_rule -> gini
#         max_depth -> 5
#         min_bucket -> 1
#         mtry -> 6
#         alpha -> 0.1
#         handle_outliers -> False
#         weight_classes -> False
#         uniform_strength -> 0
#       ------------------------------------------------------
#
#     **********************************************************
#
# **********************************************************
# TRAINING STARTED...
# TREE (0) (took: 0.02 mins).
# TREE (1) (took: 0.13 mins).
# TREE (2) (took: 0.02 mins).
# TREE (3) (took: 0.03 mins).
# TREE (4) (took: 0.02 mins).
# TREE (5) (took: 0.02 mins).
# TREE (6) (took: 0.02 mins).
#
# TRAINING FINISHED!
#
# TRAINING TOOK: 0.25 mins.
# **********************************************************
#
#
#     **********************************************************
#                        RANDOM FOREST MODEL
#
#       ------------------ Hyperparameters -------------------
#         num_trees -> 7
#         sample_size -> 1
#         replace -> False
#         splitting_rule -> gini
#         max_depth -> 5
#         min_bucket -> 1
#         mtry -> 6
#         alpha -> 1
#         handle_outliers -> False
#         weight_classes -> False
#         uniform_strength -> 0
#       ------------------------------------------------------
#
#     **********************************************************
#
# **********************************************************
# TRAINING STARTED...
#
# TREE (0) (took: 0.97 mins).
# TREE (1) (took: 1.17 mins).
# TREE (2) (took: 0.97 mins).
# TREE (3) (took: 0.75 mins).
# TREE (4) (took: 1.28 mins).
# TREE (5) (took: 1.12 mins).
# TREE (6) (took: 1.17 mins).
#
# TRAINING FINISHED!
#
# TRAINING TOOK: 7.42 mins.
# **********************************************************
#
#
#     **********************************************************
#                        RANDOM FOREST MODEL
#
#       ------------------ Hyperparameters -------------------
#         num_trees -> 8
#         sample_size -> 1
#         replace -> False
#         splitting_rule -> gini
#         max_depth -> 5
#         min_bucket -> 1
#         mtry -> 6
#         alpha -> 0.01
#         handle_outliers -> False
#         weight_classes -> False
#         uniform_strength -> 0
#       ------------------------------------------------------
#
#     **********************************************************
#
# **********************************************************
# TRAINING STARTED...
#
# TREE (0) (took: 0.0 mins).
# TREE (1) (took: 0.02 mins).
# TREE (2) (took: 0.0 mins).
# TREE (3) (took: 0.02 mins).
# TREE (4) (took: 0.0 mins).
# TREE (5) (took: 0.02 mins).
# TREE (6) (took: 0.0 mins).
# TREE (7) (took: 0.0 mins).
#
# TRAINING FINISHED!
#
# TRAINING TOOK: 0.05 mins.
# **********************************************************
#
#
#     **********************************************************
#                        RANDOM FOREST MODEL
#
#       ------------------ Hyperparameters -------------------
#         num_trees -> 8
#         sample_size -> 1
#         replace -> False
#         splitting_rule -> gini
#         max_depth -> 5
#         min_bucket -> 1
#         mtry -> 6
#         alpha -> 0.05
#         handle_outliers -> False
#         weight_classes -> False
#         uniform_strength -> 0
#       ------------------------------------------------------
#
#     **********************************************************
#
# **********************************************************
# TRAINING STARTED...
#
# TREE (0) (took: 0.02 mins).
# TREE (1) (took: 0.02 mins).
# TREE (2) (took: 0.02 mins).
# TREE (3) (took: 0.02 mins).
# TREE (4) (took: 0.02 mins).
# TREE (5) (took: 0.02 mins).
# TREE (6) (took: 0.02 mins).
# TREE (7) (took: 0.0 mins).
#
# TRAINING FINISHED!
#
# TRAINING TOOK: 0.12 mins.
# **********************************************************
#
#
#     **********************************************************
#                        RANDOM FOREST MODEL
#
#       ------------------ Hyperparameters -------------------
#         num_trees -> 8
#         sample_size -> 1
#         replace -> False
#         splitting_rule -> gini
#         max_depth -> 5
#         min_bucket -> 1
#         mtry -> 6
#         alpha -> 0.1
#         handle_outliers -> False
#         weight_classes -> False
#         uniform_strength -> 0
#       ------------------------------------------------------
#
#     **********************************************************
#
# **********************************************************
# TRAINING STARTED...
#
# TREE (0) (took: 0.08 mins).
# TREE (1) (took: 0.07 mins).
# TREE (2) (took: 0.02 mins).
# TREE (3) (took: 0.02 mins).
# TREE (4) (took: 0.02 mins).
# TREE (5) (took: 0.03 mins).
# TREE (6) (took: 0.07 mins).
# TREE (7) (took: 0.02 mins).
#
# TRAINING FINISHED!
#
# TRAINING TOOK: 0.32 mins.
# **********************************************************
#
#
#     **********************************************************
#                        RANDOM FOREST MODEL
#
#       ------------------ Hyperparameters -------------------
#         num_trees -> 8
#         sample_size -> 1
#         replace -> False
#         splitting_rule -> gini
#         max_depth -> 5
#         min_bucket -> 1
#         mtry -> 6
#         alpha -> 1
#         handle_outliers -> False
#         weight_classes -> False
#         uniform_strength -> 0
#       ------------------------------------------------------
#
#     **********************************************************
#
# **********************************************************
# TRAINING STARTED...
#
# TREE (0) (took: 1.65 mins).
# TREE (1) (took: 1.32 mins).
# TREE (2) (took: 1.4 mins).
# TREE (3) (took: 1.32 mins).
# TREE (4) (took: 1.12 mins).
# TREE (5) (took: 1.17 mins).
# TREE (6) (took: 1.5 mins).
# TREE (7) (took: 1.4 mins).
#
# TRAINING FINISHED!
#
# TRAINING TOOK: 10.87 mins.
# **********************************************************
#
#
#     **********************************************************
#                        RANDOM FOREST MODEL
#
#       ------------------ Hyperparameters -------------------
#         num_trees -> 9
#         sample_size -> 1
#         replace -> False
#         splitting_rule -> gini
#         max_depth -> 5
#         min_bucket -> 1
#         mtry -> 6
#         alpha -> 0.01
#         handle_outliers -> False
#         weight_classes -> False
#         uniform_strength -> 0
#       ------------------------------------------------------
#
#     **********************************************************
#
# **********************************************************
# TRAINING STARTED...
#
# TREE (0) (took: 0.0 mins).
# TREE (1) (took: 0.02 mins).
# TREE (2) (took: 0.02 mins).
# TREE (3) (took: 0.02 mins).
# TREE (4) (took: 0.0 mins).
# TREE (5) (took: 0.0 mins).
# TREE (6) (took: 0.0 mins).
# TREE (7) (took: 0.02 mins).
# TREE (8) (took: 0.02 mins).
#
# TRAINING FINISHED!
#
# TRAINING TOOK: 0.08 mins.
# **********************************************************
#     **********************************************************
#                        RANDOM FOREST MODEL
#
#       ------------------ Hyperparameters -------------------
#         num_trees -> 9
#         sample_size -> 1
#         replace -> False
#         splitting_rule -> gini
#         max_depth -> 5
#         min_bucket -> 1
#         mtry -> 6
#         alpha -> 0.05
#         handle_outliers -> False
#         weight_classes -> False
#         uniform_strength -> 0
#       ------------------------------------------------------
#
#     **********************************************************
#
# **********************************************************
# TRAINING STARTED...
#
# TREE (0) (took: 0.0 mins).
# TREE (1) (took: 0.02 mins).
# TREE (2) (took: 0.0 mins).
# TREE (3) (took: 0.02 mins).
# TREE (4) (took: 0.02 mins).
# TREE (5) (took: 0.02 mins).
# TREE (6) (took: 0.02 mins).
# TREE (7) (took: 0.02 mins).
# TREE (8) (took: 0.0 mins).
#
# TRAINING FINISHED!
#
# TRAINING TOOK: 0.1 mins.
# **********************************************************
#
#
#     **********************************************************
#                        RANDOM FOREST MODEL
#
#       ------------------ Hyperparameters -------------------
#         num_trees -> 9
#         sample_size -> 1
#         replace -> False
#         splitting_rule -> gini
#         max_depth -> 5
#         min_bucket -> 1
#         mtry -> 6
#         alpha -> 0.1
#         handle_outliers -> False
#         weight_classes -> False
#         uniform_strength -> 0
#       ------------------------------------------------------
#
#     **********************************************************
#
# **********************************************************
# TRAINING STARTED...
#
# TREE (0) (took: 0.02 mins).
# TREE (1) (took: 0.02 mins).
# TREE (2) (took: 0.02 mins).
# TREE (3) (took: 0.08 mins).
# TREE (4) (took: 0.08 mins).
# TREE (5) (took: 0.02 mins).
# TREE (6) (took: 0.02 mins).
# TREE (7) (took: 0.02 mins).
# TREE (8) (took: 0.12 mins).
#
# TRAINING FINISHED!
#
# TRAINING TOOK: 0.38 mins.
# **********************************************************
#
#
#     **********************************************************
#                        RANDOM FOREST MODEL
#
#       ------------------ Hyperparameters -------------------
#         num_trees -> 9
#         sample_size -> 1
#         replace -> False
#         splitting_rule -> gini
#         max_depth -> 5
#         min_bucket -> 1
#         mtry -> 6
#         alpha -> 1
#         handle_outliers -> False
#         weight_classes -> False
#         uniform_strength -> 0
#       ------------------------------------------------------
#
#     **********************************************************
#
# **********************************************************
# TRAINING STARTED...
#
# TREE (0) (took: 1.18 mins).
# TREE (1) (took: 1.03 mins).
# TREE (2) (took: 0.98 mins).
# TREE (3) (took: 1.37 mins).
# TREE (4) (took: 0.88 mins).
# TREE (5) (took: 0.83 mins).
# TREE (6) (took: 0.83 mins).
# TREE (7) (took: 1.23 mins).
# TREE (8) (took: 1.15 mins).
#
# TRAINING FINISHED!
#
# TRAINING TOOK: 9.5 mins.
# **********************************************************
#
#
#     **********************************************************
#                        RANDOM FOREST MODEL
#
#       ------------------ Hyperparameters -------------------
#         num_trees -> 10
#         sample_size -> 1
#         replace -> False
#         splitting_rule -> gini
#         max_depth -> 5
#         min_bucket -> 1
#         mtry -> 6
#         alpha -> 0.01
#         handle_outliers -> False
#         weight_classes -> False
#         uniform_strength -> 0
#       ------------------------------------------------------
#
#     **********************************************************
#
# **********************************************************
# TRAINING STARTED...
#
# TREE (0) (took: 0.02 mins).
# TREE (1) (took: 0.0 mins).
# TREE (2) (took: 0.0 mins).
# TREE (3) (took: 0.0 mins).
# TREE (4) (took: 0.0 mins).
# TREE (5) (took: 0.0 mins).
# TREE (6) (took: 0.0 mins).
# TREE (7) (took: 0.02 mins).
# TREE (8) (took: 0.0 mins).
# TREE (9) (took: 0.02 mins).
#
# TRAINING FINISHED!
#
# TRAINING TOOK: 0.05 mins.
# **********************************************************
#
#
#     **********************************************************
#                        RANDOM FOREST MODEL
#
#       ------------------ Hyperparameters -------------------
#         num_trees -> 10
#         sample_size -> 1
#         replace -> False
#         splitting_rule -> gini
#         max_depth -> 5
#         min_bucket -> 1
#         mtry -> 6
#         alpha -> 0.05
#         handle_outliers -> False
#         weight_classes -> False
#         uniform_strength -> 0
#       ------------------------------------------------------
#
#     **********************************************************
#
# **********************************************************
# TRAINING STARTED...
#
# TREE (0) (took: 0.0 mins).
# TREE (1) (took: 0.02 mins).
# TREE (2) (took: 0.02 mins).
# TREE (3) (took: 0.02 mins).
# TREE (4) (took: 0.0 mins).
# TREE (5) (took: 0.02 mins).
# TREE (6) (took: 0.02 mins).
# TREE (7) (took: 0.02 mins).
# TREE (8) (took: 0.08 mins).
# TREE (9) (took: 0.02 mins).
#
# TRAINING FINISHED!
#
# TRAINING TOOK: 0.2 mins.
# **********************************************************
#
#
#     **********************************************************
#                        RANDOM FOREST MODEL
#
#       ------------------ Hyperparameters -------------------
#         num_trees -> 10
#         sample_size -> 1
#         replace -> False
#         splitting_rule -> gini
#         max_depth -> 5
#         min_bucket -> 1
#         mtry -> 6
#         alpha -> 0.1
#         handle_outliers -> False
#         weight_classes -> False
#         uniform_strength -> 0
#       ------------------------------------------------------
#
#     **********************************************************
#
# **********************************************************
# TRAINING STARTED...
#
# TREE (0) (took: 0.02 mins).
# TREE (1) (took: 0.02 mins).
# TREE (2) (took: 0.02 mins).
# TREE (3) (took: 0.02 mins).
# TREE (4) (took: 0.07 mins).
# TREE (5) (took: 0.02 mins).
# TREE (6) (took: 0.07 mins).
# TREE (7) (took: 0.13 mins).
# TREE (8) (took: 0.02 mins).
# TREE (9) (took: 0.02 mins).
#
# TRAINING FINISHED!
#
# TRAINING TOOK: 0.38 mins.
# **********************************************************
#
#
#     **********************************************************
#                        RANDOM FOREST MODEL
#
#       ------------------ Hyperparameters -------------------
#         num_trees -> 10
#         sample_size -> 1
#         replace -> False
#         splitting_rule -> gini
#         max_depth -> 5
#         min_bucket -> 1
#         mtry -> 6
#         alpha -> 1
#         handle_outliers -> False
#         weight_classes -> False
#         uniform_strength -> 0
#       ------------------------------------------------------
#
#     **********************************************************
#
# **********************************************************
# TRAINING STARTED...
# TREE (0) (took: 1.17 mins).
# TREE (1) (took: 1.23 mins).
# TREE (2) (took: 1.0 mins).
# TREE (3) (took: 1.48 mins).
# TREE (4) (took: 1.25 mins).
# TREE (5) (took: 0.98 mins).
# TREE (6) (took: 1.07 mins).
# TREE (7) (took: 1.08 mins).
# TREE (8) (took: 1.3 mins).
# TREE (9) (took: 1.3 mins).
#
# TRAINING FINISHED!
#
# TRAINING TOOK: 11.87 mins.
# **********************************************************
#
# 								*** RECALL -> TRAIN SET ***
# 								*** RECALL -> TEST SET ***
# 								*** AVERAGE TRAIN RECALL THROUGH 5 RUNS ***
# 								*** AVERAGE TEST RECALL THROUGH 5 RUNS ***

# %% [markdown]
# # 3. Impact calculation

# %% [markdown]
# ## --- 3.1. Class 0 ---

# %%
df_implact_0 = evaluations_test_class_0_avg.copy()

for col in [0.01, 0.05, 0.1]:
    df_implact_0 = (df_implact_0
                    .assign(Absolute=lambda x: (x[col] - x[1]))
                    .assign(Relative=lambda x: (x['Absolute'] / x[1])*100)
                    .rename(columns={
                                        "Absolute": f"{col} - 1.0 (Absolute)",
                                        "Relative": f"{col} - 1.0 (Relative)"
                                    }
                           )
                   )
    
for col in [0.01, 0.05, 0.1]:
    print(f"Class: {col} - 1.0.\n")
    print(f"Mean Absolute Performance Difference: " + str(round(df_implact_0[f"{col} - 1.0 (Absolute)"].mean(), 3)) + ".")
    print(f"Mean Relative Performance Difference: " + str(round(df_implact_0[f"{col} - 1.0 (Relative)"].mean(), 3)) + " %.")
    print("------------------------------------------------------------")
# Out:
# Class: 0.01 - 1.0.
#
# Mean Absolute Performance Difference: 0.055.
# Mean Relative Performance Difference: 6.139 %.
# ------------------------------------------------------------
# Class: 0.05 - 1.0.
#
# Mean Absolute Performance Difference: 0.057.
# Mean Relative Performance Difference: 6.334 %.
# ------------------------------------------------------------
# Class: 0.1 - 1.0.
#
# Mean Absolute Performance Difference: 0.061.
# Mean Relative Performance Difference: 6.811 %.
# ------------------------------------------------------------

# %% [markdown]
# ## --- 3.2. Class 1 ---

# %%
df_implact_1 = evaluations_test_class_1_avg.copy()

for col in [0.01, 0.05, 0.1]:
    df_implact_1 = (df_implact_1
                    .assign(Absolute=lambda x: (x[col] - x[1]))
                    .assign(Relative=lambda x: (x['Absolute'] / x[1])*100)
                    .rename(columns={
                                        "Absolute": f"{col} - 1.0 (Absolute)",
                                        "Relative": f"{col} - 1.0 (Relative)"
                                    }
                           )
                   )
    
for col in [0.01, 0.05, 0.1]:
    print(f"Class: {col} - 1.0.\n")
    print(f"Mean Absolute Performance Difference: " + str(round(df_implact_1[f"{col} - 1.0 (Absolute)"].mean(), 3)) + ".")
    print(f"Mean Relative Performance Difference: " + str(round(df_implact_1[f"{col} - 1.0 (Relative)"].mean(), 3)) + " %.")
    print("------------------------------------------------------------")
# Out:
# Class: 0.01 - 1.0.
#
# Mean Absolute Performance Difference: -0.021.
# Mean Relative Performance Difference: -3.499 %.
# ------------------------------------------------------------
# Class: 0.05 - 1.0.
#
# Mean Absolute Performance Difference: -0.038.
# Mean Relative Performance Difference: -6.42 %.
# ------------------------------------------------------------
# Class: 0.1 - 1.0.
#
# Mean Absolute Performance Difference: -0.042.
# Mean Relative Performance Difference: -7.184 %.
# ------------------------------------------------------------

# %% [markdown]
# ## --- 3.3. Time Measurement ---

# %%
df_time_impact = time_measurements_avg.copy()

for col in [0.01, 0.05, 0.1]:
    df_time_impact = (df_time_impact
                      .assign(Absolute=lambda x: (x[col] - x[1]))
                      .assign(Relative=lambda x: (x['Absolute'] / x[1])*100)
                      .rename(columns={
                                          "Absolute": f"{col} - 1.0 (Absolute)",
                                          "Relative": f"{col} - 1.0 (Relative)"
                                      }
                             )  
                     )
    
for col in [0.01, 0.05, 0.1]:
    print(f"Class: {col} - 1.0.\n")
    print(f"Mean Absolute Performance Difference: " + str(round(df_time_impact[f"{col} - 1.0 (Absolute)"].mean(), 2)) + ".")
    print(f"Mean Relative Performance Difference: " + str(round(df_time_impact[f"{col} - 1.0 (Relative)"].mean(), 2)) + " %.")
    print("------------------------------------------------------------")
# Out:
# Class: 0.01 - 1.0.
#
# Mean Absolute Performance Difference: -9.73.
# Mean Relative Performance Difference: -97.56 %.
# ------------------------------------------------------------
# Class: 0.05 - 1.0.
#
# Mean Absolute Performance Difference: -9.65.
# Mean Relative Performance Difference: -96.77 %.
# ------------------------------------------------------------
# Class: 0.1 - 1.0.
#
# Mean Absolute Performance Difference: -9.51.
# Mean Relative Performance Difference: -95.38 %.
# ------------------------------------------------------------
